# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [raw]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>

# %% [raw]
# <style>
# .output_wrapper .ui-dialog-titlebar {
#   display: none;
# }
# </style>

# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
from ipywidgets import *
from IPython.display import display
from ipywidgets import widgets
import gmaps
import gmaps.datasets

import numpy as np

# %%
gAPI = "AIzaSyC9HZIkVEV3eg6Q4jb6ZkQFHlkHcPY_PtI"
gmaps.configure(api_key=gAPI)

# %% [markdown]
# # SAMPLE DASHBOARD

# %%
# displaying the text widget
text = widgets.Text(description="Range", width=200)
display(text)

output = widgets.Label()
display(output)

# preparing the plot 

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('time (s)')
ax.set_ylabel('voltage (mV)')
plt.show()

# function to deal with the added domain name
def handle_submit(sender):
    try:
        t = np.arange(0.0, float(text.value), 0.01)
        s = 1 + np.sin(2*np.pi*t)
        ax.clear()
        ax.set_xlabel('time (s)')
        ax.set_ylabel('voltage (mV)')
        ax.plot(t, s)
    except:
        output.value = 'Invalid Input'

text.on_submit(handle_submit)
# Out:
# Text(value='', description='Range')
# Label(value='')
# <img src="data:image/png;base64,..." width="733">

# %%
locations = gmaps.datasets.load_dataset("taxi_rides")
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations))
fig
# Out:
# Figure()
